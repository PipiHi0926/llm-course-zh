# %% [markdown]
# <p style="font-size:small; color:gray;"> Author: 鄭永誠, Year: 2024 </p>
#
# # 搭配Langsmith追蹤LLM架構流程和使用狀況
# ------------------
#
# ## 基本介紹
# ![image.png](attachment:image.png)
#
# ## 使用方法
#
# - 1. 去[官網](https://www.langchain.com/langsmith)註冊
# - 2. 至官網[Settings頁面](https://smith.langchain.com/o/a986d0cb-a916-5744-a1cc-92d719b98e7c/settings)申請 API
# - 3. 下載套件 (如果你有鑰使用到他套件下的traceable，這邊先不示範)
# - 4. 終端機上設定變數(注意，我這邊是用window系統操作使用setx；mac應該是用export )

# %%
""" 下載套件 """
# %pip install langsmith -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 專端機上執行這些，更改變數設定
#
# ```
# setx LANGCHAIN_TRACING_V2 true
# setx LANGCHAIN_ENDPOINT "https://api.smith.langchain.com"
# setx LANGCHAIN_API_KEY '你的金鑰'
# setx LANGCHAIN_PROJECT "你的project名稱"
# ```

# %% [markdown]
# ### 此時，你再執行操作一次C6範例 (當然其他也可以)
#
# langsmith 網站上，應該會出現操作紀錄、異常操作紀錄、各節點輸入輸出值
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
